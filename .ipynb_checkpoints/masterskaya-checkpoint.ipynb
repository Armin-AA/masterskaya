# %% [markdown]
# - Заказчик: Благотворительный фонд “Бюро добрых дел”
# - Основная цель заказчика заключается в том, чтобы из пула тех клиентов, которые жертвовали за последний год, выявить клиентов, которые могут увеличить частоту или размер пожертвований.
# - Данные, которыми располагает заказчик, включают в себя историю платежей жертвователей и какую-то дополнительную информацию за несколько лет по четырём тысячам жертвователей.
# - Жизненный цикл жертвователя составляет от полутора до трёх лет, поэтому в истории будут примеры того, как именно меняется характер платежей клиентов.
# - Если получится на основе данных сделать дополнительную сегментацию, например выделить характерное поведение пользователей, которые прекращают жертвовать, это также интересует заказчика.
# - Данные реальные, задача интересная, успешное её решение приведёт к тому, что больше людей получат ту помощь, в которой нуждаются.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')
import phik
import lightgbm as lgb
import shap

from phik.report import plot_correlation_matrix
from sklearn.model_selection import train_test_split
from phik import resources, report
from tqdm import tqdm
from sklearn import preprocessing
from IPython.display import Image
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

from sklearn.metrics import mean_absolute_percentage_error

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# %%
donors = pd.read_excel('/Users/armineagajanyan/Downloads/Выгрузка для ЯП_2.xlsx', sheet_name='Доноры')
donats = pd.read_excel('/Users/armineagajanyan/Downloads/Выгрузка для ЯП_2.xlsx', sheet_name='Пожертвования')

# %%
#создадим функцию для информации
def table_info(df):
    display(df.info())
    display(df.head())
    display(df.describe())
    display(df.isna().mean())
    return df

# %% [markdown]
# # Датасет donors

# %%
table_info(donors)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               3683 non-null   object
#  1   Пол                              2431 non-null   object
#  2   Город                            1015 non-null   object
#  3   Дата последней email активности  1835 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 115.2+ KB
# None
#                                      ID  \
# 0  AF575B85-917F-475D-8875-00055586E05B
# 1  229A9B43-3A15-4A48-8CB6-000EDB240D50
# 2  C6606486-05A8-4437-ACF9-00344E54FEE1
# 3  6ED86154-A688-4A11-868F-006209035413
# 4  46C41E20-EA56-4698-9C37-00692FD6FFE8
#
#                                                  Пол Город  \
# 0                                                NaN   NaN
# 1                                                NaN   NaN
# 2                                                NaN   NaN
# 3  Женский                                       ...   NaN
# 4  Женский                                       ...   NaN
#
#   Дата последней email активности
# 0                             NaT
# 1                             NaT
# 2                             NaT
# 3                             NaT
# 4                             NaT
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                                           ID  \
# count                                   3683
# unique                                  3683
# top     AF575B85-917F-475D-8875-00055586E05B
# freq                                       1
# first                                    NaN
# last                                     NaN
#
#                                                       Пол   Город  \
# count                                                2431    1015
# unique                                                  2     234
# top     Женский                                       ...  Москва
# freq                                                 1874     458
# first                                                 NaN     NaN
# last                                                  NaN     NaN
#
#        Дата последней email активности
# count                             1835
# unique                             653
# top                2022-07-18 16:29:49
# freq                               294
# first              2020-01-30 11:41:46
# last               2022-07-28 20:34:28
# ID                                 0.000000
# Пол                                0.339940
# Город                              0.724409
# Дата последней email активности    0.501765
# dtype: float64
#                                         ID  \
# 0     AF575B85-917F-475D-8875-00055586E05B
# 1     229A9B43-3A15-4A48-8CB6-000EDB240D50
# 2     C6606486-05A8-4437-ACF9-00344E54FEE1
# 3     6ED86154-A688-4A11-868F-006209035413
# 4     46C41E20-EA56-4698-9C37-00692FD6FFE8
# ...                                    ...
# 3678  C5E55606-9BFC-48C0-BE7F-FFC10A10DF20
# 3679  3CB754A9-7B08-40FB-A350-FFDB291DA9E1
# 3680  3F073C3B-E567-428E-B16F-FFE09A8D2CE0
# 3681  029C3CEE-2381-4050-8E91-FFE3030218D4
# 3682  B7B85C92-A071-4D15-A8AD-FFF3107199DA
#
#                                                     Пол      Город  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3     Женский                                       ...        NaN
# 4     Женский                                       ...        NaN
# ...                                                 ...        ...
# 3678  Женский                                       ...        NaN
# 3679                                                NaN        NaN
# 3680  Женский                                       ...        NaN
# 3681  Женский                                       ...      КУШВА
# 3682  Женский                                       ...  Волгоград
#
#      Дата последней email активности
# 0                                NaT
# 1                                NaT
# 2                                NaT
# 3                                NaT
# 4                                NaT
# ...                              ...
# 3678                             NaT
# 3679                             NaT
# 3680             2022-07-18 16:29:34
# 3681                             NaT
# 3682             2020-10-08 17:42:07
#
# [3683 rows x 4 columns]

# %%
donors['Пол'].value_counts(dropna=False).to_frame()
# Out:
#                                                      Пол
# Женский                                        ...  1874
# NaN                                                 1252
# Мужской                                        ...   557

# %%
#топ 10 городов
donors['Город'].value_counts(dropna=False).to_frame().head(10)
# Out:
#                  Город
# NaN               2668
# Москва             458
# Санкт-Петербург     78
# Краснодар           23
# Нижний Новгород     20
# Новосибирск         19
# Якутск              14
# Саратов             13
# Ростов-на-Дону      12
# Казань              11

# %%
donors['Дата последней email активности'].value_counts(dropna=False).to_frame()
# Out:
#                      Дата последней email активности
# NaT                                             1848
# 2022-07-18 16:29:49                              294
# 2022-07-18 16:29:48                              229
# 2022-07-18 16:29:50                              163
# 2022-07-18 16:29:47                              114
# ...                                              ...
# 2022-06-24 19:09:13                                1
# 2022-07-19 10:00:01                                1
# 2022-07-18 17:22:28                                1
# 2022-07-22 09:42:47                                1
# 2020-10-08 17:42:07                                1
#
# [654 rows x 1 columns]

# %%
donors['Дата последней email активности'].value_counts(dropna=False)
# Out:
# NaT                    1848
# 2022-07-18 16:29:49     294
# 2022-07-18 16:29:48     229
# 2022-07-18 16:29:50     163
# 2022-07-18 16:29:47     114
#                        ...
# 2022-06-24 19:09:13       1
# 2022-07-19 10:00:01       1
# 2022-07-18 17:22:28       1
# 2022-07-22 09:42:47       1
# 2020-10-08 17:42:07       1
# Name: Дата последней email активности, Length: 654, dtype: int64

# %% [markdown]
# # Датасет donats

# %%
table_info(donats)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14043 entries, 0 to 14042
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Donor ID            14043 non-null  object
#  1   Дата платежа        14043 non-null  datetime64[ns]
#  2   Сумма платежа       14043 non-null  float64
#  3   Рекуррентный        14043 non-null  object
#  4   Назначение платежа  12774 non-null  object
#  5   Канал оплаты        14043 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 658.4+ KB
# None
#                                Donor ID        Дата платежа  Сумма платежа  \
# 0  DE5393F9-9585-4057-B7FB-24B69697FC08 2022-07-03 19:49:48          300.0
# 1  81CD4BEF-443E-4D36-B34F-664E11182D65 2020-03-14 12:20:02          300.0
# 2  D3BEB76D-D8B6-47E2-8109-44F1B278943B 2022-04-07 00:00:00           16.0
# 3  F1310736-B229-4AAC-99B7-F13ACECF67CB 2019-12-26 02:25:42          300.0
# 4  61C3D86B-39DA-445C-9D7F-9924CE9BDA14 2021-06-26 01:26:07          200.0
#
#                                         Рекуррентный  \
# 0  Да                                            ...
# 1  Нет                                           ...
# 2  Нет                                           ...
# 3  Нет                                           ...
# 4  Да                                            ...
#
#                               Назначение платежа                  Канал оплаты
# 0                       ПОЖЕРТВОВАНИЕ  undefined            Банковские карты
# 1                                        SMS bdd                         SMS
# 2  Добровольное пожертвование. НДС не облагается  Прямые поступления на счет
# 3                                            NaN                         SMS
# 4                       ПОЖЕРТВОВАНИЕ  undefined            Банковские карты
#        Сумма платежа
# count   1.404300e+04
# mean    1.720846e+03
# std     2.949977e+04
# min     1.000000e-02
# 25%     1.500000e+02
# 50%     3.500000e+02
# 75%     7.000000e+02
# max     3.000000e+06
# Donor ID              0.000000
# Дата платежа          0.000000
# Сумма платежа         0.000000
# Рекуррентный          0.000000
# Назначение платежа    0.090365
# Канал оплаты          0.000000
# dtype: float64
#                                    Donor ID        Дата платежа  \
# 0      DE5393F9-9585-4057-B7FB-24B69697FC08 2022-07-03 19:49:48
# 1      81CD4BEF-443E-4D36-B34F-664E11182D65 2020-03-14 12:20:02
# 2      D3BEB76D-D8B6-47E2-8109-44F1B278943B 2022-04-07 00:00:00
# 3      F1310736-B229-4AAC-99B7-F13ACECF67CB 2019-12-26 02:25:42
# 4      61C3D86B-39DA-445C-9D7F-9924CE9BDA14 2021-06-26 01:26:07
# ...                                     ...                 ...
# 14038  0B6DA68C-558B-4153-806E-B1D775585B88 2015-12-12 14:50:34
# 14039  793690C0-6332-4289-96B4-2CF8902ACEF5 2020-12-02 09:59:13
# 14040  69613503-5B71-4690-ACB5-8E783FF915B4 2021-12-26 00:00:00
# 14041  144B2E46-2A6A-48DE-92FB-729C3897A2B4 2018-11-27 16:35:01
# 14042  EAD75CE6-0F33-478E-A37E-712C66DB9082 2020-05-27 22:49:33
#
#        Сумма платежа                                       Рекуррентный  \
# 0              300.0  Да                                            ...
# 1              300.0  Нет                                           ...
# 2               16.0  Нет                                           ...
# 3              300.0  Нет                                           ...
# 4              200.0  Да                                            ...
# ...              ...                                                ...
# 14038          100.0  Да                                            ...
# 14039          200.0  Да                                            ...
# 14040          500.0  Нет                                           ...
# 14041          200.0  Да                                            ...
# 14042        10000.0  Да                                            ...
#
#                                       Назначение платежа  \
# 0                               ПОЖЕРТВОВАНИЕ  undefined
# 1                                                SMS bdd
# 2          Добровольное пожертвование. НДС не облагается
# 3                                                    NaN
# 4                               ПОЖЕРТВОВАНИЕ  undefined
# ...                                                  ...
# 14038  Пожертвование в фонд помощи детям-отказникам и...
# 14039                                      ПОЖЕРТВОВАНИЕ
# 14040      Добровольное пожертвование. НДС не облагается
# 14041  Пожертвование в фонд помощи детям-отказникам и...
# 14042                                      ПОЖЕРТВОВАНИЕ
#
#                        Канал оплаты
# 0                Банковские карты
# 1                             SMS
# 2      Прямые поступления на счет
# 3                             SMS
# 4                Банковские карты
# ...                             ...
# 14038            Банковские карты
# 14039            Банковские карты
# 14040  Прямые поступления на счет
# 14041            Банковские карты
# 14042            Банковские карты
#
# [14043 rows x 6 columns]

# %%
donats['Дата платежа'].min(), donats['Дата платежа'].max()
# Out:
# (Timestamp('2015-07-19 20:10:11'), Timestamp('2022-07-28 19:22:15'))

# %%
donats['Дата платежа'].hist(figsize = (15, 5), bins=100)
# Out:
# <AxesSubplot:>

# %%
donats[donats['Дата платежа'].between('2022-01-01', '2022-07-01')].hist(figsize = (15, 5), bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Дата платежа'}>,
#         <AxesSubplot:title={'center':'Сумма платежа'}>]], dtype=object)

# %%
donats[donats['Дата платежа'].between('2021-07-18', '2021-07-30')].hist(figsize = (15, 5), bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'Дата платежа'}>,
#         <AxesSubplot:title={'center':'Сумма платежа'}>]], dtype=object)

# %%
donats['Сумма платежа'].describe().round()
# Out:
# count      14043.0
# mean        1721.0
# std        29500.0
# min            0.0
# 25%          150.0
# 50%          350.0
# 75%          700.0
# max      3000000.0
# Name: Сумма платежа, dtype: float64

# %%
donats['Сумма платежа'].plot(figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
donats.boxplot(column=['Сумма платежа'], figsize = (15, 5))
# Out:
# <AxesSubplot:>

# %%
donats['Рекуррентный'].value_counts(dropna=True).to_frame()
# Out:
#                                                     Рекуррентный
# Да                                             ...          8085
# Нет                                            ...          5958

# %%
donats['Назначение платежа'].value_counts(dropna=True).to_frame().head(70)
# Out:
#                                                     Назначение платежа
# ПОЖЕРТВОВАНИЕ                                                     3811
# Пожертвование в фонд помощи детям-отказникам и ...                3335
# ПОЖЕРТВОВАНИЕ  undefined                                          2162
# Добровольное пожертвование. НДС не облагается                      497
# SMS bdd                                                            253
# ...                                                                ...
# На обучение Дарьи                                                   12
# Фотомастерская для Февронии                                         11
# На программу Окно в мир                                             11
# День рождения со смыслом                                            11
# Соц.квартиры в Костроме                                             11
#
# [70 rows x 1 columns]

# %% [markdown]
# # №2. Предобработка данных

# %%
# сравним количество уникальных id в обеих датасетах
display(len(donors['ID'].unique()))
len(donats['Donor ID'].unique())
# Out:
# 3683
# 3683

# %%
#проверим на дубликаты
'Количество дубликатов:', donors.duplicated().sum()
# Out:
# ('Количество дубликатов:', 0)

# %%
#проверим на дубликаты
'Количество дубликатов:', donats.duplicated().sum()
# Out:
# ('Количество дубликатов:', 12)

# %%
donats[donats.duplicated() == True]
# Out:
#                                    Donor ID Дата платежа  Сумма платежа  \
# 133    5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 297    5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 1438   5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 2837   5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 5166   FFCCBA23-89CA-4A22-BD8A-7CAD2D9EB7F7   2021-09-13           20.0
# 7654   FFCCBA23-89CA-4A22-BD8A-7CAD2D9EB7F7   2021-09-13           20.0
# 9594   D38F6A22-9BEF-4484-B377-ED8ED1DB4553   2021-02-11            1.0
# 10112  FFCCBA23-89CA-4A22-BD8A-7CAD2D9EB7F7   2021-09-13           20.0
# 10685  5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 11757  5D288F50-4F0E-4FDF-A026-863590DF3F69   2022-04-28            1.0
# 13775  8FBCD1D4-5490-496F-A089-FB39AB7975AF   2021-04-12           10.0
# 13990  C6CA05F1-C324-46EE-8A5A-7B1302DBB149   2020-12-27          100.0
#
#                                             Рекуррентный  \
# 133    Нет                                           ...
# 297    Нет                                           ...
# 1438   Нет                                           ...
# 2837   Нет                                           ...
# 5166   Нет                                           ...
# 7654   Нет                                           ...
# 9594   Нет                                           ...
# 10112  Нет                                           ...
# 10685  Нет                                           ...
# 11757  Нет                                           ...
# 13775  Нет                                           ...
# 13990  Нет                                           ...
#
#                                       Назначение платежа  \
# 133                 БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 297                 БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 1438                БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 2837                БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 5166       Добровольное пожертвование. НДС не облагается
# 7654       Добровольное пожертвование. НДС не облагается
# 9594   ДОБРОВОЛЬНОЕ ПОЖЕРТВОВАНИЕ;Сумма 1.00 руб.;Ком...
# 10112      Добровольное пожертвование. НДС не облагается
# 10685               БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 11757               БЛАГОТВОРИТЕЛЬНОЕ ПОЖЕРТВОВАНИЕ 1.00
# 13775      Добровольное пожертвование. НДС не облагается
# 13990  ДОБРОВОЛЬНОЕ ПОЖЕРТВОВАНИЕ;Сумма 100 руб.;Коми...
#
#                        Канал оплаты
# 133    Прямые поступления на счет
# 297    Прямые поступления на счет
# 1438   Прямые поступления на счет
# 2837   Прямые поступления на счет
# 5166   Прямые поступления на счет
# 7654   Прямые поступления на счет
# 9594   Прямые поступления на счет
# 10112  Прямые поступления на счет
# 10685  Прямые поступления на счет
# 11757  Прямые поступления на счет
# 13775  Прямые поступления на счет
# 13990  Прямые поступления на счет

# %%
#eдаляем дубликаты и проверяем
donats = donats.drop_duplicates()
donats.duplicated().sum()
# Out:
# 0

# %%
display(len(donors['ID'].unique()))
len(donats['Donor ID'].unique())
# Out:
# 3683
# 3683

# %%
# т.к. количество уникальных id равны, объединим таблицы в одну,
# предварительно переименовав столбец в donats

donats = donats.rename(columns={'Donor ID' : 'ID'})

df = donats.merge(donors, how='left', on = 'ID')
df.head()
# Out:
#                                      ID        Дата платежа  Сумма платежа  \
# 0  DE5393F9-9585-4057-B7FB-24B69697FC08 2022-07-03 19:49:48          300.0
# 1  81CD4BEF-443E-4D36-B34F-664E11182D65 2020-03-14 12:20:02          300.0
# 2  D3BEB76D-D8B6-47E2-8109-44F1B278943B 2022-04-07 00:00:00           16.0
# 3  F1310736-B229-4AAC-99B7-F13ACECF67CB 2019-12-26 02:25:42          300.0
# 4  61C3D86B-39DA-445C-9D7F-9924CE9BDA14 2021-06-26 01:26:07          200.0
#
#                                         Рекуррентный  \
# 0  Да                                            ...
# 1  Нет                                           ...
# 2  Нет                                           ...
# 3  Нет                                           ...
# 4  Да                                            ...
#
#                               Назначение платежа  \
# 0                       ПОЖЕРТВОВАНИЕ  undefined
# 1                                        SMS bdd
# 2  Добровольное пожертвование. НДС не облагается
# 3                                            NaN
# 4                       ПОЖЕРТВОВАНИЕ  undefined
#
#                    Канал оплаты  \
# 0            Банковские карты
# 1                         SMS
# 2  Прямые поступления на счет
# 3                         SMS
# 4            Банковские карты
#
#                                                  Пол   Город  \
# 0  Женский                                       ...  Москва
# 1  Женский                                       ...  Москва
# 2  Мужской                                       ...     NaN
# 3                                                NaN     NaN
# 4  Женский                                       ...     NaN
#
#   Дата последней email активности
# 0             2022-06-03 20:15:57
# 1             2022-07-18 17:19:02
# 2                             NaT
# 3                             NaT
# 4             2022-07-20 20:32:37

# %%
len(donats['ID'].unique())
# Out:
# 3683

# %%
# переименуем столбцы, приведя их к змеиному регистру
df = df.rename(columns = 
              {
                  'ID':'id',
                  'Дата платежа':'date',
                  'Сумма платежа':'amount',
                  'Пол':'gender',
                  'Город':'city',
                  'Назначение платежа' : 'purpose',
                  'Рекуррентный' : 'is_reccurent',
                  'Канал оплаты' : 'channel',
                  'Дата последней email активности': 'last_email_activity'
                  
              }
              )
df.columns
# Out:
# Index(['id', 'date', 'amount', 'is_reccurent', 'purpose', 'channel', 'gender',
#        'city', 'last_email_activity'],
#       dtype='object')

# %%
# посмотрим процентное соотношение пропусков
df.isna().mean()
# Out:
# id                     0.000000
# date                   0.000000
# amount                 0.000000
# is_reccurent           0.000000
# purpose                0.090443
# channel                0.000000
# gender                 0.111824
# city                   0.519849
# last_email_activity    0.210819
# dtype: float64

# %%
#посмотрим тип данных
df.dtypes
# Out:
# id                             object
# date                   datetime64[ns]
# amount                        float64
# is_reccurent                   object
# purpose                        object
# channel                        object
# gender                         object
# city                           object
# last_email_activity    datetime64[ns]
# dtype: object

# %%
#заполним пропуски в категориальных признаков no_info 
for column in ['gender', 'purpose', 'city']:            
    df[column].fillna('no_info', inplace=True)

# %%
# посмотрим процентное соотношение пропусков
df.isna().mean()
# Out:
# id                     0.000000
# date                   0.000000
# amount                 0.000000
# is_reccurent           0.000000
# purpose                0.000000
# channel                0.000000
# gender                 0.000000
# city                   0.000000
# last_email_activity    0.210819
# dtype: float64

# %% [markdown]
# #построим графики
# sns.pairplot(df)
# #корреляция Пирсона
# df.corr().style.background_gradient()

# %% [markdown]
# phik_overview = df.phik_matrix()

# %% [raw]
# phik_overview['amount'].sort_values(ascending=False)

# %% [raw]
# plot_correlation_matrix(phik_overview.values,
#                         x_labels=phik_overview.columns,
#                         y_labels=phik_overview.index,
#                         vmin=0, vmax=1, color_map="Greens",
#                         title=r"correlation $\phi_K$",
#                         fontsize_factor=1.5,
#                         figsize=(10, 10))
# plt.tight_layout()

# %%
#приведем датасет к нижнему регистру
df = df.apply(lambda x: x.str.lower() if(x.dtype == 'object') else x)

# %%
#df['day_year'] = pd.DatetimeIndex(df['date']).year
#df['last_email_activity_year'] = pd.DatetimeIndex(df['last_email_activity']).year
#df['day_month'] = pd.DatetimeIndex(df['date']).month
#df['last_email_activity_month'] = pd.DatetimeIndex(df['last_email_activity']).month

#добавляем столбец lifetime: дейсвие договора в месяцах
#df['lifetime'] = (df['last_email_activity_year'] - df['day_year']) * 365 + (df['last_email_activity_month']
#                - df['day_month']) * 30

#df.loc[df['lifetime'] == 0, 'lifetime'] = 1

# %%
#df['is_reccurent'] = df['is_reccurent'].replace('Нет...', '0').replace('Да...', '1').astype('int')

# %%
# заменяем полное название фонда
df['purpose'] = (df['purpose']
                 .str
                 .replace('пожертвование в фонд помощи детям-отказникам и детям-сиротам "бюро добрых дел"', 'пожертвование'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14031 entries, 0 to 14030
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   14031 non-null  object
#  1   date                 14031 non-null  datetime64[ns]
#  2   amount               14031 non-null  float64
#  3   is_reccurent         14031 non-null  object
#  4   purpose              14030 non-null  object
#  5   channel              14031 non-null  object
#  6   gender               14031 non-null  object
#  7   city                 14031 non-null  object
#  8   last_email_activity  11073 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(6)
# memory usage: 1.1+ MB

# %% [raw]
# # поменяем тип данных float64 на int8
# for col in ['']:
#     df[col] = df[col].astype('int8')

# %%
df['date_day'] =df['date'].dt.day
df['date_month'] =df['date'].dt.month
df['date_year'] =df['date'].dt.year

df['last_email_activity_day'] =df['last_email_activity'].dt.day

df['last_email_activity_month'] =df['last_email_activity'].dt.month
df['last_email_activity_year'] =df['last_email_activity'].dt.year

# %%
df.head()
# Out:
#                                      id                date  amount  \
# 0  de5393f9-9585-4057-b7fb-24b69697fc08 2022-07-03 19:49:48   300.0
# 1  81cd4bef-443e-4d36-b34f-664e11182d65 2020-03-14 12:20:02   300.0
# 2  d3beb76d-d8b6-47e2-8109-44f1b278943b 2022-04-07 00:00:00    16.0
# 3  f1310736-b229-4aac-99b7-f13acecf67cb 2019-12-26 02:25:42   300.0
# 4  61c3d86b-39da-445c-9d7f-9924ce9bda14 2021-06-26 01:26:07   200.0
#
#                                         is_reccurent  \
# 0  да                                            ...
# 1  нет                                           ...
# 2  нет                                           ...
# 3  нет                                           ...
# 4  да                                            ...
#
#                                          purpose  \
# 0                       пожертвование  undefined
# 1                                        sms bdd
# 2  добровольное пожертвование. ндс не облагается
# 3                                        no_info
# 4                       пожертвование  undefined
#
#                         channel  \
# 0            банковские карты
# 1                         sms
# 2  прямые поступления на счет
# 3                         sms
# 4            банковские карты
#
#                                               gender     city  \
# 0  женский                                       ...   москва
# 1  женский                                       ...   москва
# 2  мужской                                       ...  no_info
# 3                                            no_info  no_info
# 4  женский                                       ...  no_info
#
#   last_email_activity  date_day  date_month  date_year  \
# 0 2022-06-03 20:15:57         3           7       2022
# 1 2022-07-18 17:19:02        14           3       2020
# 2                 NaT         7           4       2022
# 3                 NaT        26          12       2019
# 4 2022-07-20 20:32:37        26           6       2021
#
#    last_email_activity_day  last_email_activity_month  \
# 0                      3.0                        6.0
# 1                     18.0                        7.0
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                     20.0                        7.0
#
#    last_email_activity_year
# 0                    2022.0
# 1                    2022.0
# 2                       NaN
# 3                       NaN
# 4                    2022.0

# %%
df[df['id']=='DE5393F9-9585-4057-B7FB-24B69697FC08']
# Out:
# Empty DataFrame
# Columns: [id, date, amount, is_reccurent, purpose, channel, gender, city, last_email_activity, date_day, date_month, date_year, last_email_activity_day, last_email_activity_month, last_email_activity_year]
# Index: []

# %%
df[df['id']=='2c65d134-af3b-4a17-afce-72159c28da67']
# Out:
#                                         id                date  amount  \
# 8660  2c65d134-af3b-4a17-afce-72159c28da67 2019-09-01 17:30:24   350.0
#
#                                            is_reccurent  purpose channel  \
# 8660  нет                                           ...  no_info   sms
#
#        gender     city last_email_activity  date_day  date_month  date_year  \
# 8660  no_info  no_info                 NaT         1           9       2019
#
#       last_email_activity_day  last_email_activity_month  \
# 8660                      NaN                        NaN
#
#       last_email_activity_year
# 8660                       NaN

# %%
plt.figure(figsize=(15,8))
df['last_email_activity'].hist()
# Out:
# <AxesSubplot:>

# %%
df = df.sort_values(['id', 'date'], ascending=[True, True])
df['life_time'] = df.groupby('id')['date'].apply(lambda x: x.diff().fillna(pd.Timedelta(0)))#.cumsum())

# %%
df[df['id']=='de5393f9-9585-4057-b7fb-24b69697fc08']
# Out:
#                                          id                date  amount  \
# 831    de5393f9-9585-4057-b7fb-24b69697fc08 2020-12-30 11:42:20   100.0
# 1552   de5393f9-9585-4057-b7fb-24b69697fc08 2020-12-30 11:54:50   300.0
# 7168   de5393f9-9585-4057-b7fb-24b69697fc08 2021-01-30 11:42:47   100.0
# 10505  de5393f9-9585-4057-b7fb-24b69697fc08 2021-02-28 11:42:35   100.0
# 3894   de5393f9-9585-4057-b7fb-24b69697fc08 2021-03-30 11:42:31   100.0
# 13348  de5393f9-9585-4057-b7fb-24b69697fc08 2021-04-30 11:42:41   100.0
# 6174   de5393f9-9585-4057-b7fb-24b69697fc08 2021-05-30 11:42:37   100.0
# 2442   de5393f9-9585-4057-b7fb-24b69697fc08 2021-06-30 11:42:51   100.0
# 13035  de5393f9-9585-4057-b7fb-24b69697fc08 2021-07-30 11:42:33   100.0
# 4495   de5393f9-9585-4057-b7fb-24b69697fc08 2021-08-30 12:45:51   100.0
# 12491  de5393f9-9585-4057-b7fb-24b69697fc08 2021-09-30 11:42:55   100.0
# 11167  de5393f9-9585-4057-b7fb-24b69697fc08 2021-10-30 11:42:30   100.0
# 12807  de5393f9-9585-4057-b7fb-24b69697fc08 2021-11-30 11:43:28   100.0
# 2725   de5393f9-9585-4057-b7fb-24b69697fc08 2021-12-04 12:56:05   500.0
# 7904   de5393f9-9585-4057-b7fb-24b69697fc08 2021-12-30 11:43:06   100.0
# 1493   de5393f9-9585-4057-b7fb-24b69697fc08 2022-01-04 12:56:38   500.0
# 8094   de5393f9-9585-4057-b7fb-24b69697fc08 2022-01-30 11:42:39   100.0
# 13747  de5393f9-9585-4057-b7fb-24b69697fc08 2022-02-28 11:43:06   100.0
# 8479   de5393f9-9585-4057-b7fb-24b69697fc08 2022-03-30 11:43:09   100.0
# 3635   de5393f9-9585-4057-b7fb-24b69697fc08 2022-06-03 19:49:08   300.0
# 0      de5393f9-9585-4057-b7fb-24b69697fc08 2022-07-03 19:49:48   300.0
#
#                                             is_reccurent  \
# 831    да                                            ...
# 1552   нет                                           ...
# 7168   да                                            ...
# 10505  да                                            ...
# 3894   да                                            ...
# 13348  да                                            ...
# 6174   да                                            ...
# 2442   да                                            ...
# 13035  да                                            ...
# 4495   да                                            ...
# 12491  да                                            ...
# 11167  да                                            ...
# 12807  да                                            ...
# 2725   да                                            ...
# 7904   да                                            ...
# 1493   да                                            ...
# 8094   да                                            ...
# 13747  да                                            ...
# 8479   да                                            ...
# 3635   да                                            ...
# 0      да                                            ...
#
#                                       purpose             channel  \
# 831                  пожертвование  undefined  банковские карты
# 1552   на психологические консультации артёму  банковские карты
# 7168                 пожертвование  undefined  банковские карты
# 10505                пожертвование  undefined  банковские карты
# 3894                 пожертвование  undefined  банковские карты
# 13348                пожертвование  undefined  банковские карты
# 6174                 пожертвование  undefined  банковские карты
# 2442                 пожертвование  undefined  банковские карты
# 13035                пожертвование  undefined  банковские карты
# 4495                 пожертвование  undefined  банковские карты
# 12491                пожертвование  undefined  банковские карты
# 11167                пожертвование  undefined  банковские карты
# 12807                пожертвование  undefined  банковские карты
# 2725                 пожертвование  undefined  банковские карты
# 7904                 пожертвование  undefined  банковские карты
# 1493                 пожертвование  undefined  банковские карты
# 8094                 пожертвование  undefined  банковские карты
# 13747                пожертвование  undefined  банковские карты
# 8479                 пожертвование  undefined  банковские карты
# 3635                 пожертвование  undefined  банковские карты
# 0                    пожертвование  undefined  банковские карты
#
#                                                   gender    city  \
# 831    женский                                       ...  москва
# 1552   женский                                       ...  москва
# 7168   женский                                       ...  москва
# 10505  женский                                       ...  москва
# 3894   женский                                       ...  москва
# 13348  женский                                       ...  москва
# 6174   женский                                       ...  москва
# 2442   женский                                       ...  москва
# 13035  женский                                       ...  москва
# 4495   женский                                       ...  москва
# 12491  женский                                       ...  москва
# 11167  женский                                       ...  москва
# 12807  женский                                       ...  москва
# 2725   женский                                       ...  москва
# 7904   женский                                       ...  москва
# 1493   женский                                       ...  москва
# 8094   женский                                       ...  москва
# 13747  женский                                       ...  москва
# 8479   женский                                       ...  москва
# 3635   женский                                       ...  москва
# 0      женский                                       ...  москва
#
#       last_email_activity  date_day  date_month  date_year  \
# 831   2022-06-03 20:15:57        30          12       2020
# 1552  2022-06-03 20:15:57        30          12       2020
# 7168  2022-06-03 20:15:57        30           1       2021
# 10505 2022-06-03 20:15:57        28           2       2021
# 3894  2022-06-03 20:15:57        30           3       2021
# 13348 2022-06-03 20:15:57        30           4       2021
# 6174  2022-06-03 20:15:57        30           5       2021
# 2442  2022-06-03 20:15:57        30           6       2021
# 13035 2022-06-03 20:15:57        30           7       2021
# 4495  2022-06-03 20:15:57        30           8       2021
# 12491 2022-06-03 20:15:57        30           9       2021
# 11167 2022-06-03 20:15:57        30          10       2021
# 12807 2022-06-03 20:15:57        30          11       2021
# 2725  2022-06-03 20:15:57         4          12       2021
# 7904  2022-06-03 20:15:57        30          12       2021
# 1493  2022-06-03 20:15:57         4           1       2022
# 8094  2022-06-03 20:15:57        30           1       2022
# 13747 2022-06-03 20:15:57        28           2       2022
# 8479  2022-06-03 20:15:57        30           3       2022
# 3635  2022-06-03 20:15:57         3           6       2022
# 0     2022-06-03 20:15:57         3           7       2022
#
#        last_email_activity_day  last_email_activity_month  \
# 831                        3.0                        6.0
# 1552                       3.0                        6.0
# 7168                       3.0                        6.0
# 10505                      3.0                        6.0
# 3894                       3.0                        6.0
# 13348                      3.0                        6.0
# 6174                       3.0                        6.0
# 2442                       3.0                        6.0
# 13035                      3.0                        6.0
# 4495                       3.0                        6.0
# 12491                      3.0                        6.0
# 11167                      3.0                        6.0
# 12807                      3.0                        6.0
# 2725                       3.0                        6.0
# 7904                       3.0                        6.0
# 1493                       3.0                        6.0
# 8094                       3.0                        6.0
# 13747                      3.0                        6.0
# 8479                       3.0                        6.0
# 3635                       3.0                        6.0
# 0                          3.0                        6.0
#
#        last_email_activity_year        life_time
# 831                      2022.0  0 days 00:00:00
# 1552                     2022.0  0 days 00:12:30
# 7168                     2022.0 30 days 23:47:57
# 10505                    2022.0 28 days 23:59:48
# 3894                     2022.0 29 days 23:59:56
# 13348                    2022.0 31 days 00:00:10
# 6174                     2022.0 29 days 23:59:56
# 2442                     2022.0 31 days 00:00:14
# 13035                    2022.0 29 days 23:59:42
# 4495                     2022.0 31 days 01:03:18
# 12491                    2022.0 30 days 22:57:04
# 11167                    2022.0 29 days 23:59:35
# 12807                    2022.0 31 days 00:00:58
# 2725                     2022.0  4 days 01:12:37
# 7904                     2022.0 25 days 22:47:01
# 1493                     2022.0  5 days 01:13:32
# 8094                     2022.0 25 days 22:46:01
# 13747                    2022.0 29 days 00:00:27
# 8479                     2022.0 30 days 00:00:03
# 3635                     2022.0 65 days 08:05:59
# 0                        2022.0 30 days 00:00:40

# %%
df.head()
# Out:
#                                          id                date  amount  \
# 9904   0001afdd-94e3-48f3-b5e7-d5539700425e 2019-04-26 19:19:24   100.0
# 13529  000711b2-2785-461b-bf5b-5cb7d2caba20 2020-03-27 08:23:58   500.0
# 1628   000711b2-2785-461b-bf5b-5cb7d2caba20 2020-04-29 08:24:29   500.0
# 10917  000711b2-2785-461b-bf5b-5cb7d2caba20 2020-05-28 08:24:10   500.0
# 4608   000711b2-2785-461b-bf5b-5cb7d2caba20 2020-07-27 08:24:02   500.0
#
#                                             is_reccurent        purpose  \
# 9904   нет                                           ...        no_info
# 13529  да                                            ...  пожертвование
# 1628   да                                            ...  пожертвование
# 10917  да                                            ...  пожертвование
# 4608   да                                            ...  пожертвование
#
#                   channel                                             gender  \
# 9904                sms                                              no_info
# 13529  банковские карты    женский                                       ...
# 1628   банковские карты    женский                                       ...
# 10917  банковские карты    женский                                       ...
# 4608   банковские карты    женский                                       ...
#
#           city last_email_activity  date_day  date_month  date_year  \
# 9904   no_info                 NaT        26           4       2019
# 13529  no_info 2022-07-27 10:16:14        27           3       2020
# 1628   no_info 2022-07-27 10:16:14        29           4       2020
# 10917  no_info 2022-07-27 10:16:14        28           5       2020
# 4608   no_info 2022-07-27 10:16:14        27           7       2020
#
#        last_email_activity_day  last_email_activity_month  \
# 9904                       NaN                        NaN
# 13529                     27.0                        7.0
# 1628                      27.0                        7.0
# 10917                     27.0                        7.0
# 4608                      27.0                        7.0
#
#        last_email_activity_year        life_time
# 9904                        NaN  0 days 00:00:00
# 13529                    2022.0  0 days 00:00:00
# 1628                     2022.0 33 days 00:00:31
# 10917                    2022.0 28 days 23:59:41
# 4608                     2022.0 59 days 23:59:52

# %%
for column in ['last_email_activity','last_email_activity_day', 'last_email_activity_month', 'last_email_activity_year']:            
    df[column].fillna(0, inplace=True)
df['purpose'].fillna('no_info', inplace=True)

# %%
df.isna().mean()
# Out:
# id                           0.0
# date                         0.0
# amount                       0.0
# is_reccurent                 0.0
# purpose                      0.0
# channel                      0.0
# gender                       0.0
# city                         0.0
# last_email_activity          0.0
# date_day                     0.0
# date_month                   0.0
# date_year                    0.0
# last_email_activity_day      0.0
# last_email_activity_month    0.0
# last_email_activity_year     0.0
# life_time                    0.0
# dtype: float64

# %% [raw]
# #создадим целевой признак
# df['churn'] = 0
# df.loc[df['last_email_activity'] == 1, 'churn'] = 1
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14031 entries, 9904 to 12503
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         14031 non-null  object
#  1   date                       14031 non-null  datetime64[ns]
#  2   amount                     14031 non-null  float64
#  3   is_reccurent               14031 non-null  object
#  4   purpose                    14031 non-null  object
#  5   channel                    14031 non-null  object
#  6   gender                     14031 non-null  object
#  7   city                       14031 non-null  object
#  8   last_email_activity        14031 non-null  object
#  9   date_day                   14031 non-null  int64
#  10  date_month                 14031 non-null  int64
#  11  date_year                  14031 non-null  int64
#  12  last_email_activity_day    14031 non-null  float64
#  13  last_email_activity_month  14031 non-null  float64
#  14  last_email_activity_year   14031 non-null  float64
#  15  life_time                  14031 non-null  timedelta64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(7), timedelta64[ns](1)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#                                          id                date  amount  \
# 9904   0001afdd-94e3-48f3-b5e7-d5539700425e 2019-04-26 19:19:24   100.0
# 13529  000711b2-2785-461b-bf5b-5cb7d2caba20 2020-03-27 08:23:58   500.0
# 1628   000711b2-2785-461b-bf5b-5cb7d2caba20 2020-04-29 08:24:29   500.0
# 10917  000711b2-2785-461b-bf5b-5cb7d2caba20 2020-05-28 08:24:10   500.0
# 4608   000711b2-2785-461b-bf5b-5cb7d2caba20 2020-07-27 08:24:02   500.0
#
#                                             is_reccurent        purpose  \
# 9904   нет                                           ...        no_info
# 13529  да                                            ...  пожертвование
# 1628   да                                            ...  пожертвование
# 10917  да                                            ...  пожертвование
# 4608   да                                            ...  пожертвование
#
#                   channel                                             gender  \
# 9904                sms                                              no_info
# 13529  банковские карты    женский                                       ...
# 1628   банковские карты    женский                                       ...
# 10917  банковские карты    женский                                       ...
# 4608   банковские карты    женский                                       ...
#
#           city  last_email_activity  date_day  date_month  date_year  \
# 9904   no_info                    0        26           4       2019
# 13529  no_info  2022-07-27 10:16:14        27           3       2020
# 1628   no_info  2022-07-27 10:16:14        29           4       2020
# 10917  no_info  2022-07-27 10:16:14        28           5       2020
# 4608   no_info  2022-07-27 10:16:14        27           7       2020
#
#        last_email_activity_day  last_email_activity_month  \
# 9904                       0.0                        0.0
# 13529                     27.0                        7.0
# 1628                      27.0                        7.0
# 10917                     27.0                        7.0
# 4608                      27.0                        7.0
#
#        last_email_activity_year        life_time
# 9904                        0.0  0 days 00:00:00
# 13529                    2022.0  0 days 00:00:00
# 1628                     2022.0 33 days 00:00:31
# 10917                    2022.0 28 days 23:59:41
# 4608                     2022.0 59 days 23:59:52

# %%
# проверим дисбаланс классов
#df['churn'].value_counts(normalize=True)

# %%
#df['lifetime'].fillna(1, inplace=True)

# %%
#df= df.groupby('id').apply(lambda x: x.loc[x['date'] == x['date'].max(), 'date']-x.loc[x['date'] == x['date'].min(), 'date'])

# %%
df.sample(10)
# Out:
#                                          id                date  amount  \
# 10701  25481b9a-6069-491f-82a1-ba4f91608a4e 2017-02-28 23:45:22  5000.0
# 5651   11f5d2d0-9dfc-4227-bede-5cd0ab1a5b23 2021-10-01 16:35:51   150.0
# 207    193fbef8-9c3e-4581-bbdf-a5d3ef653ae1 2017-10-23 16:00:09   500.0
# 3436   935a10a0-688b-4150-a8d5-8304e5151d79 2019-07-31 07:30:20   300.0
# 2149   94f524b8-8087-4b9f-b26e-58f23fb6611b 2020-12-24 17:57:01   500.0
# 9735   05343f01-7d7a-4147-8ece-74f6f8da69a8 2020-08-19 12:55:55  1000.0
# 5534   126c89a1-a19e-40bf-bfab-c756c9d7f923 2021-02-28 17:43:44   100.0
# 7030   4112bfd7-78a1-48d3-9585-97d05b1d920e 2021-11-04 11:03:55  1000.0
# 5154   dcf467f5-e832-4e67-9642-aa931fbbdf53 2021-12-20 00:00:00    50.0
# 10847  d1b590f0-7a7f-427f-99a6-67603c6fd13c 2019-04-27 19:15:37   100.0
#
#                                             is_reccurent  \
# 10701  да                                            ...
# 5651   да                                            ...
# 207    да                                            ...
# 3436   нет                                           ...
# 2149   да                                            ...
# 9735   да                                            ...
# 5534   да                                            ...
# 7030   да                                            ...
# 5154   нет                                           ...
# 10847  нет                                           ...
#
#                                              purpose  \
# 10701                                  пожертвование
# 5651                        пожертвование  undefined
# 207                                    пожертвование
# 3436                                   пожертвование
# 2149                                   пожертвование
# 9735                        пожертвование  undefined
# 5534                        пожертвование  undefined
# 7030                        пожертвование  undefined
# 5154   добровольное пожертвование. ндс не облагается
# 10847                                        no_info
#
#                             channel  \
# 10701            банковские карты
# 5651             банковские карты
# 207              банковские карты
# 3436             банковские карты
# 2149             банковские карты
# 9735             банковские карты
# 5534             банковские карты
# 7030             банковские карты
# 5154   прямые поступления на счет
# 10847                         sms
#
#                                                   gender       city  \
# 10701  женский                                       ...    no_info
# 5651   женский                                       ...  волгоград
# 207    мужской                                       ...     москва
# 3436                                             no_info    no_info
# 2149   женский                                       ...     москва
# 9735   женский                                       ...     москва
# 5534   женский                                       ...     москва
# 7030   женский                                       ...     москва
# 5154   мужской                                       ...    no_info
# 10847                                            no_info    no_info
#
#        last_email_activity  date_day  date_month  date_year  \
# 10701  2022-07-18 16:29:33        28           2       2017
# 5651   2022-07-18 16:29:48         1          10       2021
# 207    2022-07-18 16:29:47        23          10       2017
# 3436   2022-07-18 16:29:49        31           7       2019
# 2149   2022-07-18 23:23:46        24          12       2020
# 9735   2022-07-18 19:48:43        19           8       2020
# 5534   2022-07-18 16:29:48        28           2       2021
# 7030   2022-07-18 16:29:47         4          11       2021
# 5154                     0        20          12       2021
# 10847                    0        27           4       2019
#
#        last_email_activity_day  last_email_activity_month  \
# 10701                     18.0                        7.0
# 5651                      18.0                        7.0
# 207                       18.0                        7.0
# 3436                      18.0                        7.0
# 2149                      18.0                        7.0
# 9735                      18.0                        7.0
# 5534                      18.0                        7.0
# 7030                      18.0                        7.0
# 5154                       0.0                        0.0
# 10847                      0.0                        0.0
#
#        last_email_activity_year        life_time
# 10701                    2022.0 30 days 00:00:13
# 5651                     2022.0 30 days 00:00:10
# 207                      2022.0 30 days 00:00:13
# 3436                     2022.0  0 days 00:00:00
# 2149                     2022.0  3 days 19:36:51
# 9735                     2022.0 30 days 23:59:57
# 5534                     2022.0 29 days 23:59:51
# 7030                     2022.0 31 days 00:00:27
# 5154                        0.0  0 days 00:00:00
# 10847                       0.0  0 days 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14031 entries, 9904 to 12503
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         14031 non-null  object
#  1   date                       14031 non-null  datetime64[ns]
#  2   amount                     14031 non-null  float64
#  3   is_reccurent               14031 non-null  object
#  4   purpose                    14031 non-null  object
#  5   channel                    14031 non-null  object
#  6   gender                     14031 non-null  object
#  7   city                       14031 non-null  object
#  8   last_email_activity        14031 non-null  object
#  9   date_day                   14031 non-null  int64
#  10  date_month                 14031 non-null  int64
#  11  date_year                  14031 non-null  int64
#  12  last_email_activity_day    14031 non-null  float64
#  13  last_email_activity_month  14031 non-null  float64
#  14  last_email_activity_year   14031 non-null  float64
#  15  life_time                  14031 non-null  timedelta64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(7), timedelta64[ns](1)
# memory usage: 1.8+ MB

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# # amount

# %%
df['amount'].describe().T.round(3)
# Out:
# count      14031.000
# mean        1722.305
# std        29512.340
# min            0.010
# 25%          150.000
# 50%          350.000
# 75%          700.000
# max      3000000.000
# Name: amount, dtype: float64

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df['amount'], orient = 'h')
plt.title('Распределение величины пожертвования')
plt.show()

# %%
df.groupby('id')['amount'].agg(['count','sum', 'mean', 'median']).sort_values(by='sum', ascending=False)
# Out:
#                                       count         sum          mean  \
# id
# 29c903a6-ae15-40fc-81fa-4f58d06f3139      1  3000000.00  3.000000e+06
# 99a56103-5bdb-4c2b-af08-0ef1a3d4dc37     52  2138989.00  4.113440e+04
# 99d83c2d-f72a-4c58-9641-782996644f81      1  1000000.00  1.000000e+06
# 4a6e53ad-4134-499f-8fa5-fbbea120687a     21   701100.00  3.338571e+04
# 6ec0197e-4a86-47b6-a3ed-d9b6981bd4fe      1   500000.00  5.000000e+05
# ...                                     ...         ...           ...
# 420cc3d4-1252-43ad-9d07-5b8d08f37d01      1        0.48  4.800000e-01
# fc1eb8bd-b30f-47a8-b347-0200183861d8      1        0.22  2.200000e-01
# 162031b6-7b03-40d7-b27a-4c7f49d5dacc      1        0.01  1.000000e-02
# b5d24c69-9326-4605-a30c-c855d19fc867      1        0.01  1.000000e-02
# b0b6eb05-ac83-4772-a2be-89901bca336f      1        0.01  1.000000e-02
#
#                                           median
# id
# 29c903a6-ae15-40fc-81fa-4f58d06f3139  3000000.00
# 99a56103-5bdb-4c2b-af08-0ef1a3d4dc37      100.00
# 99d83c2d-f72a-4c58-9641-782996644f81  1000000.00
# 4a6e53ad-4134-499f-8fa5-fbbea120687a      100.00
# 6ec0197e-4a86-47b6-a3ed-d9b6981bd4fe   500000.00
# ...                                          ...
# 420cc3d4-1252-43ad-9d07-5b8d08f37d01        0.48
# fc1eb8bd-b30f-47a8-b347-0200183861d8        0.22
# 162031b6-7b03-40d7-b27a-4c7f49d5dacc        0.01
# b5d24c69-9326-4605-a30c-c855d19fc867        0.01
# b0b6eb05-ac83-4772-a2be-89901bca336f        0.01
#
# [3683 rows x 4 columns]

# %%
df.groupby('id')['amount'].agg(['count','sum', 'mean', 'median']).sort_values(by='count', ascending=False)
# Out:
#                                       count       sum         mean  median
# id
# 8a8daecd-40b3-4a41-b53c-06a62be672e6     83  129500.0  1560.240964  1000.0
# 0b6da68c-558b-4153-806e-b1d775585b88     76   13500.0   177.631579   200.0
# f836f738-fb7e-4134-aba8-b6e9ca1e71ea     76    2280.0    30.000000    30.0
# 85348172-f358-4345-91f1-db8cf0531c8a     73   17202.0   235.643836   100.0
# 4ecb767f-8830-497b-b395-851d4eacd1f8     65   93500.0  1438.461538  1500.0
# ...                                     ...       ...          ...     ...
# 6246ed33-cf41-4f33-88f3-7002a436e483      1     100.0   100.000000   100.0
# 6254900a-bddc-4b1d-ab9a-9877b9e7bc77      1     500.0   500.000000   500.0
# 62602f1f-b33b-4a10-a17a-aea4adb4791d      1     300.0   300.000000   300.0
# 626c5441-75d2-45e9-bbc9-4502685f23bd      1     200.0   200.000000   200.0
# ffebaa14-fde5-4a6d-9363-fe84a18d68bc      1     500.0   500.000000   500.0
#
# [3683 rows x 4 columns]

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data = df.groupby('id')['amount'].mean(), orient='h')            
plt.ticklabel_format(style='plain', axis='x')
plt.title('Распределение средней суммы пожертвования на донора')
plt.show()

# %%
# посмотрим соотношение между городом и общей суммой пожертвований

city_total_sum = df.groupby('city', as_index=False)['amount'].agg(['count','sum', 'mean', 'median'])
city_total_sum = city_total_sum.sort_values(by='sum', ascending=False)
city_total_sum.head(20)
# Out:
#                    count          sum          mean   median
# city
# москва              3643  11878614.00   3260.668131    500.0
# no_info             7294   9078598.01   1244.666577    300.0
# санкт-петербург      494    815789.16   1651.395061    300.0
# якутск               132    204273.00   1547.522727   1000.0
# мытищи                93    183050.00   1968.279570   2500.0
# краснодар            223    182761.00    819.556054    200.0
# san jose              20    158500.00   7925.000000   5000.0
# frankfurt am main     83    129500.00   1560.240964   1000.0
# самара                90    125416.00   1393.511111    500.0
# ростов-на-дону        82     98805.00   1204.939024   1000.0
# одинцово              72     93862.00   1303.638889    500.0
# сочи                  76     75415.00    992.302632    100.0
# fort lauderdale        7     70000.00  10000.000000  10000.0
# helsinki              29     65675.00   2264.655172   1000.0
# лыткарино              4     50000.00  12500.000000  15000.0
# екатеринбург          93     47265.00    508.225806    300.0
# riga                   5     46000.00   9200.000000   3000.0
# королев                7     30500.00   4357.142857   5000.0
# вольск                 1     29988.00  29988.000000  29988.0
# балашиха               4     29450.00   7362.500000   5250.0

# %%
df.columns
# Out:
# Index(['id', 'date', 'amount', 'is_reccurent', 'purpose', 'channel', 'gender',
#        'city', 'last_email_activity', 'date_day', 'date_month', 'date_year',
#        'last_email_activity_day', 'last_email_activity_month',
#        'last_email_activity_year', 'life_time'],
#       dtype='object')

# %%
reccurent_total_sum = df.groupby('is_reccurent', as_index=False)['amount'].agg(['count','sum', 'mean', 'median','std'])
reccurent_total_sum = reccurent_total_sum.sort_values(by='sum', ascending=False)
reccurent_total_sum.head(20)
# Out:
#                                                     count          sum  \
# is_reccurent
# нет                                            ...   5946  18307864.66
# да                                             ...   8085   5857796.00
#
#                                                            mean  median  \
# is_reccurent
# нет                                            ...  3079.021974   300.0
# да                                             ...   724.526407   500.0
#
#                                                              std
# is_reccurent
# нет                                            ...  45275.567712
# да                                             ...   1330.556718

# %%
df['date']
# Out:
# 9904    2019-04-26 19:19:24
# 13529   2020-03-27 08:23:58
# 1628    2020-04-29 08:24:29
# 10917   2020-05-28 08:24:10
# 4608    2020-07-27 08:24:02
#                 ...
# 6353    2019-04-26 20:37:02
# 4369    2021-08-29 00:00:00
# 2698    2021-09-13 00:00:00
# 5828    2021-09-19 00:00:00
# 12503   2017-04-14 21:28:03
# Name: date, Length: 14031, dtype: datetime64[ns]

# %%
df['date'].sort_index(inplace=True)

# %%
df['date'].index.is_monotonic
# Out:
# True

# %%
df['date'].hist(figsize = (15, 5), bins=100)
# Out:
# <AxesSubplot:>

# %%
df_year = df[df['date'].between('2022-01-31 00:00:00', '2022-07-02 00:00:00')]
# Out:
# Boolean Series key will be reindexed to match DataFrame index.

# %%
df_year['date'].hist(figsize = (15, 5), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# data_new =df.copy()
# #напишем функцию для создания признаков
# def make_features(data_new, max_lag, rolling_mean_size):
#     data_new['month'] = data_new.index.month
#     data_new['day'] = data_new.index.day
#     data_new['dayofweek'] = data.index.dayofweek
#     data_new['hour'] = data.index.hour
#     #получим отстающие значения знакомой функцией shift()
#     for lag in range(1, max_lag + 1):
#         data_new['lag_{}'.format(lag)] = data['num_orders'].shift(lag)
#
#     data_new['rolling_mean'] = data_new['num_orders'].shift().rolling(rolling_mean_size).mean()
#
#
# make_features(data_new, 10, 15)

# %%
lags = [6]
for lag in tqdm(lags):
    df_year["lag_" + str(lag)] = df_year.groupby("id")["amount"].shift(lag)
# Out:
#   0%|                                                     | 0/1 [00:00<?, ?it/s]
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|████████████████████████████████████████████| 1/1 [00:00<00:00, 177.71it/s]

# %%
means = [7,14]
for mns in tqdm(means):
    df_year['rolling_median_'+str(mns)] = df_year.groupby(['id'])['amount'].transform(lambda x: x.rolling(mns).median())
# Out:
#   0%|                                                     | 0/2 [00:00<?, ?it/s]
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|█████████████████████████████████████████████| 2/2 [00:00<00:00, 17.76it/s]

# %%
df_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1285 entries, 13476 to 84
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1285 non-null   object
#  1   date                       1285 non-null   datetime64[ns]
#  2   amount                     1285 non-null   float64
#  3   is_reccurent               1285 non-null   object
#  4   purpose                    1285 non-null   object
#  5   channel                    1285 non-null   object
#  6   gender                     1285 non-null   object
#  7   city                       1285 non-null   object
#  8   last_email_activity        1285 non-null   object
#  9   date_day                   1285 non-null   int64
#  10  date_month                 1285 non-null   int64
#  11  date_year                  1285 non-null   int64
#  12  last_email_activity_day    1285 non-null   float64
#  13  last_email_activity_month  1285 non-null   float64
#  14  last_email_activity_year   1285 non-null   float64
#  15  life_time                  1285 non-null   timedelta64[ns]
#  16  lag_6                      43 non-null     float64
#  17  rolling_median_7           43 non-null     float64
#  18  rolling_median_14          6 non-null      float64
# dtypes: datetime64[ns](1), float64(7), int64(3), object(7), timedelta64[ns](1)
# memory usage: 200.8+ KB

# %%
#df = df.dropna()
df_year.head()
# Out:
#                                          id                date  amount  \
# 13476  000711b2-2785-461b-bf5b-5cb7d2caba20 2019-10-27 09:51:01   500.0
# 1834   000711b2-2785-461b-bf5b-5cb7d2caba20 2019-09-10 10:27:08   500.0
# 2609   000711b2-2785-461b-bf5b-5cb7d2caba20 2021-09-27 09:59:55   500.0
# 4875   00adba34-1edc-4652-a559-1c0be379a0da 2017-02-28 11:40:00   300.0
# 10664  0112fa48-d41e-44fe-98d5-734826ce1e7c 2022-05-20 09:53:54    77.0
#
#                                             is_reccurent  \
# 13476  да                                            ...
# 1834   да                                            ...
# 2609   да                                            ...
# 4875   нет                                           ...
# 10664  нет                                           ...
#
#                                              purpose  \
# 13476                                  пожертвование
# 1834                                   пожертвование
# 2609                                   пожертвование
# 4875                              на обучение полины
# 10664  добровольное пожертвование. ндс не облагается
#
#                             channel  \
# 13476            банковские карты
# 1834             банковские карты
# 2609             банковские карты
# 4875             банковские карты
# 10664  прямые поступления на счет
#
#                                                   gender     city  \
# 13476  женский                                       ...  no_info
# 1834   женский                                       ...  no_info
# 2609   женский                                       ...  no_info
# 4875   женский                                       ...   москва
# 10664  мужской                                       ...  no_info
#
#        last_email_activity  date_day  date_month  date_year  \
# 13476  2022-07-27 10:16:14        27           2       2022
# 1834   2022-07-27 10:16:14        29           5       2022
# 2609   2022-07-27 10:16:14        27           6       2022
# 4875   2022-07-19 00:58:29        13           4       2022
# 10664                    0         1           7       2022
#
#        last_email_activity_day  last_email_activity_month  \
# 13476                     27.0                        7.0
# 1834                      27.0                        7.0
# 2609                      27.0                        7.0
# 4875                      19.0                        7.0
# 10664                      0.0                        0.0
#
#        last_email_activity_year         life_time  lag_6  rolling_median_7  \
# 13476                    2022.0  30 days 23:59:28    NaN               NaN
# 1834                     2022.0  91 days 00:00:16    NaN               NaN
# 2609                     2022.0  28 days 23:59:36    NaN               NaN
# 4875                     2022.0 407 days 23:08:31    NaN               NaN
# 10664                       0.0   0 days 00:00:00    NaN               NaN
#
#        rolling_median_14
# 13476                NaN
# 1834                 NaN
# 2609                 NaN
# 4875                 NaN
# 10664                NaN

# %%
# удаляем лишние столбцы(информация есть в столбце lifetime) 
df_year=df_year.drop([ 'date', 'last_email_activity', 'life_time'], axis=1)
#df=df[:14999].copy()

# %% [raw]
# #разделим датасет  на обучающую и тестовую выборки в соотношении 9:1
# from sklearn.model_selection import train_test_split
# train, test = train_test_split(df, shuffle=False, test_size=0.2)
# train = train.dropna()
# test = test.dropna()
#
# features_train = train.drop(['amount'], axis=1)
# target_train = train['amount']
#
# features_test = test.drop(['amount'], axis=1)
# target_test = test['amount']

# %%
#разбиваем сначала на 2 части обучающую и валидационную (60%),тестовую (40)
train, test = train_test_split(df_year, train_size=0.60, shuffle=False)   
#разбиваем  обучающую на 2 части: тестовую(50%),валидационную (50)
val, test = train_test_split(test, train_size=0.5,  shuffle=False )

# %%
print(train.index.min(), train.index.max())
print(val.index.min(), val.index.max())
print(test.index.min(), test.index.max())
print(train.shape)
print(val.shape)
print(test.shape)
# Out:
# 18 13985
# 178 13973
# 2 14021
# (771, 16)
# (257, 16)
# (257, 16)

# %%
train.shape
# Out:
# (771, 16)

# %%
test.shape
# Out:
# (257, 16)

# %%
df_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1285 entries, 13476 to 84
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         1285 non-null   object
#  1   amount                     1285 non-null   float64
#  2   is_reccurent               1285 non-null   object
#  3   purpose                    1285 non-null   object
#  4   channel                    1285 non-null   object
#  5   gender                     1285 non-null   object
#  6   city                       1285 non-null   object
#  7   date_day                   1285 non-null   int64
#  8   date_month                 1285 non-null   int64
#  9   date_year                  1285 non-null   int64
#  10  last_email_activity_day    1285 non-null   float64
#  11  last_email_activity_month  1285 non-null   float64
#  12  last_email_activity_year   1285 non-null   float64
#  13  lag_6                      43 non-null     float64
#  14  rolling_median_7           43 non-null     float64
#  15  rolling_median_14          6 non-null      float64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 170.7+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 771 entries, 13476 to 8949
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         771 non-null    object
#  1   amount                     771 non-null    float64
#  2   is_reccurent               771 non-null    object
#  3   purpose                    771 non-null    object
#  4   channel                    771 non-null    object
#  5   gender                     771 non-null    object
#  6   city                       771 non-null    object
#  7   date_day                   771 non-null    int64
#  8   date_month                 771 non-null    int64
#  9   date_year                  771 non-null    int64
#  10  last_email_activity_day    771 non-null    float64
#  11  last_email_activity_month  771 non-null    float64
#  12  last_email_activity_year   771 non-null    float64
#  13  lag_6                      17 non-null     float64
#  14  rolling_median_7           17 non-null     float64
#  15  rolling_median_14          0 non-null      float64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 102.4+ KB

# %%
df.columns
# Out:
# Index(['id', 'date', 'amount', 'is_reccurent', 'purpose', 'channel', 'gender',
#        'city', 'last_email_activity', 'date_day', 'date_month', 'date_year',
#        'last_email_activity_day', 'last_email_activity_month',
#        'last_email_activity_year', 'life_time'],
#       dtype='object')

# %%
# список призноков
X = ['id', 'is_reccurent', 'purpose', 'channel', 'gender', 'city',
       'date_day', 'date_month', 'date_year', 'last_email_activity_day',
       'last_email_activity_month','last_email_activity_year', 'lag_6',
      #'rolling_median_14', 'rolling_median_7',#'lag_14','lag_11','lag_28',
      #, 'lag_42', 'lag_49', 'lag_56',
     #'rolling_median_7',
     'rolling_median_14',
     'rolling_median_7']
       
# список целевого признака

y=['amount']

#список категориальных признаков
cat_features =['id', 'is_reccurent', 'purpose', 'channel', 'gender', 'city']

# %%
params={'eval_metric':'RMSE',
       'cat_features':cat_features,
       'random_state':42,
         'iterations':2000,
        #'learning_rate': 0.01,
        'depth':  2,
       'verbose':50}

# %%
model = CatBoostRegressor(**params)

# %% [markdown]
# train_data = Pool(data=train[X],
#                   label=train[y],
#                   cat_features=cat_features
#                  )
#
# valid_data = Pool(data=val[X],
#                   label=val[y],
#                   cat_features=cat_features
#                  )

# %%
model.fit(train[X], train[y], eval_set=(val[X],val[y]), plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Learning rate set to 0.032028
# 0:	learn: 9107.4598949	test: 7455.7552003	best: 7455.7552003 (0)	total: 58.6ms	remaining: 1m 57s
# 50:	learn: 8990.7334932	test: 7446.5813950	best: 7446.5813950 (50)	total: 85.5ms	remaining: 3.27s
# 100:	learn: 8910.0253231	test: 7455.2078809	best: 7443.0640243 (79)	total: 109ms	remaining: 2.05s
# 150:	learn: 8841.6322360	test: 7471.8254003	best: 7443.0640243 (79)	total: 136ms	remaining: 1.67s
# 200:	learn: 8760.8882058	test: 7493.3295033	best: 7443.0640243 (79)	total: 160ms	remaining: 1.44s
# 250:	learn: 8700.0725631	test: 7490.5916646	best: 7443.0640243 (79)	total: 185ms	remaining: 1.29s
# 300:	learn: 8674.4525276	test: 7500.8888787	best: 7443.0640243 (79)	total: 209ms	remaining: 1.18s
# 350:	learn: 8656.4417531	test: 7502.8088107	best: 7443.0640243 (79)	total: 232ms	remaining: 1.09s
# 400:	learn: 8557.7442858	test: 7517.1562834	best: 7443.0640243 (79)	total: 254ms	remaining: 1.01s
# 450:	learn: 8454.7319071	test: 7581.3589037	best: 7443.0640243 (79)	total: 275ms	remaining: 944ms
# 500:	learn: 8420.0060235	test: 7629.8118922	best: 7443.0640243 (79)	total: 295ms	remaining: 883ms
# 550:	learn: 8345.2625799	test: 7714.0337984	best: 7443.0640243 (79)	total: 317ms	remaining: 833ms
# 600:	learn: 8282.8303926	test: 7777.4429185	best: 7443.0640243 (79)	total: 338ms	remaining: 786ms
# 650:	learn: 8219.9095460	test: 7877.3797943	best: 7443.0640243 (79)	total: 357ms	remaining: 741ms
# 700:	learn: 8193.5646741	test: 7887.7775805	best: 7443.0640243 (79)	total: 379ms	remaining: 703ms
# 750:	learn: 8170.8212863	test: 7885.4759772	best: 7443.0640243 (79)	total: 401ms	remaining: 667ms
# 800:	learn: 8146.9598535	test: 7910.1372717	best: 7443.0640243 (79)	total: 422ms	remaining: 632ms
# 850:	learn: 8115.8734596	test: 7929.1435110	best: 7443.0640243 (79)	total: 441ms	remaining: 596ms
# 900:	learn: 8091.8770115	test: 7998.8850058	best: 7443.0640243 (79)	total: 463ms	remaining: 564ms
# 950:	learn: 8064.8676001	test: 8057.6887648	best: 7443.0640243 (79)	total: 485ms	remaining: 535ms
# 1000:	learn: 8037.7711685	test: 8068.6265704	best: 7443.0640243 (79)	total: 506ms	remaining: 505ms
# 1050:	learn: 8013.8143578	test: 8093.6528664	best: 7443.0640243 (79)	total: 531ms	remaining: 479ms
# 1100:	learn: 7995.8606261	test: 8090.0423555	best: 7443.0640243 (79)	total: 552ms	remaining: 450ms
# 1150:	learn: 7978.4806206	test: 8102.9473656	best: 7443.0640243 (79)	total: 577ms	remaining: 425ms
# 1200:	learn: 7969.4700429	test: 8113.0773002	best: 7443.0640243 (79)	total: 599ms	remaining: 398ms
# 1250:	learn: 7957.5709662	test: 8126.2723659	best: 7443.0640243 (79)	total: 616ms	remaining: 369ms
# 1300:	learn: 7945.9833824	test: 8136.5428281	best: 7443.0640243 (79)	total: 634ms	remaining: 341ms
# 1350:	learn: 7936.0915743	test: 8148.9697359	best: 7443.0640243 (79)	total: 654ms	remaining: 314ms
# 1400:	learn: 7909.2828419	test: 8207.0799162	best: 7443.0640243 (79)	total: 675ms	remaining: 289ms
# 1450:	learn: 7896.7338460	test: 8202.5462521	best: 7443.0640243 (79)	total: 696ms	remaining: 263ms
# 1500:	learn: 7884.6968408	test: 8219.8598725	best: 7443.0640243 (79)	total: 717ms	remaining: 238ms
# 1550:	learn: 7868.5684783	test: 8252.0849512	best: 7443.0640243 (79)	total: 739ms	remaining: 214ms
# 1600:	learn: 7862.9162099	test: 8262.7637377	best: 7443.0640243 (79)	total: 762ms	remaining: 190ms
# 1650:	learn: 7855.7379706	test: 8276.3547139	best: 7443.0640243 (79)	total: 780ms	remaining: 165ms
# 1700:	learn: 7844.1935893	test: 8286.4603813	best: 7443.0640243 (79)	total: 800ms	remaining: 141ms
# 1750:	learn: 7815.8139473	test: 8284.6203558	best: 7443.0640243 (79)	total: 822ms	remaining: 117ms
# 1800:	learn: 7791.5012470	test: 8270.6043475	best: 7443.0640243 (79)	total: 841ms	remaining: 92.9ms
# 1850:	learn: 7757.4608577	test: 8298.8074193	best: 7443.0640243 (79)	total: 862ms	remaining: 69.4ms
# 1900:	learn: 7731.5852048	test: 8308.3553731	best: 7443.0640243 (79)	total: 882ms	remaining: 45.9ms
# 1950:	learn: 7706.2438537	test: 8321.8877517	best: 7443.0640243 (79)	total: 904ms	remaining: 22.7ms
# 1999:	learn: 7680.7957512	test: 8291.7603145	best: 7443.0640243 (79)	total: 965ms	remaining: 0us
#
# bestTest = 7443.064024
# bestIteration = 79
#
# Shrink model to first 80 iterations.

# %%
predicted_cat = model.predict(val[X])

# %%
rmse_cat_test = mean_squared_error(test[y], predicted_cat)** 0.5

# %%
rmse_cat_test
# Out:
# 4406.435086562252

# %%
mae_cat_test = mean_absolute_error(test[y], predicted_cat)
mae_cat_test
# Out:
# 1362.1486653980478

# %%
mean_absolute_percentage_error(test[y], predicted_cat)
# Out:
# 25.175768134707944

# %%
#проверим на адекватность модели
#рассчитываем важность признаков с помощью SHAP
model.get_feature_importance(prettified=True)
# Out:
#                    Feature Id  Importances
# 0                          id    63.634991
# 1                  date_month    13.537983
# 2                      gender     7.596750
# 3                        city     6.765146
# 4                is_reccurent     4.440005
# 5                     purpose     2.512980
# 6                    date_day     1.337821
# 7   last_email_activity_month     0.137094
# 8            rolling_median_7     0.032731
# 9                       lag_6     0.004500
# 10                    channel     0.000000
# 11                  date_year     0.000000
# 12    last_email_activity_day     0.000000
# 13   last_email_activity_year     0.000000
# 14          rolling_median_14     0.000000

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# построим барчарт
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(test[X])
shap.summary_plot(shap_values, test[X], plot_type="bar", plot_size=(20,9))

# %%
# Рассмотрим SHAP-графики. Построим такой график для каждого наблюдения в датасете

shap.force_plot(explainer.expected_value, shap_values, test[X])
# Out:
# <div id='i8HWWPHK9YTNFGKNF7VWO'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 1138.4912487440126, "link": "identity", "featureNames": ["id", "is_reccurent", "purpose", "channel", "gender", "city", "date_day", "date_month", "date_year", "last_email_activity_day", "last_email_activity_month", "last_email_activity_year", "lag_6", "rolling_median_14", "rolling_median_7"], "explanations": [{"outValue": 1105.6885497316248, "simIndex": 167.0, "features": {"0": {"effect": -77.32413330097056, "value": "d185b410-aa9a-4870-b39e-9f3f38ff6cb1"}, "1": {"effect": -49.89894258648145, "value": "\u0434\u0430                                                                                                                                                                                                                                                        "}, "2": {"effect": -40.03779275910318, "value": "\u043f\u043e\u0436\u0435\u0440\u0442\u0432\u043e\u0432\u0430\u043d\u0438\u0435  undefined"}, "3": {"effect": 0.0, "value": "\u0431\u0430\u043d\u043a\u043e\u0432\u0441\u043a\u0438\u0435 \u043a\u0430\u0440\u0442\u044b  "}, "4": {"effect": 58.54702464583311, "value": "\u0436\u0435\u043d\u0441\u043a\u0438\u0439                                                                                                                                                                                                                                                   "}, "5": {"effect": 14.61787628626213, "value": "\u043c\u043e\u0441\u043a\u0432\u0430"}, "6": {"effect": -5.24006313751996, "value": 22}, "7": {"effect": 64.26819361318708, "value": 3}, "8": {"effect": 0.0, "value": 2022}, "9": {"effect": 0.0, "value": 18.0}, "10": {"effect": 2.7654993541771007, "value": 7.0}, "11": {"effect": 0.0, "value": 2022.0}, "12": {"effect": -0.20337023494269799, "value": NaN}, "13": {"effect": 0.0, "value": NaN}, "14": {"effect": -0.29699089282933266, "value": NaN}}}, {"outValue": 1026.561196198089, "simIndex": 100.0, "features": {"0": {"effect": -42.47171574973638, "value": "d185b410-aa9a-4870-b39e-9f3f38ff6cb1"}, "1": {"effect": -49.89894258648145, "value": "\u0434\u0430                                                                                                                                                                                                                                                        "}, "2": {"effect": -40.03779275910318, "value": "\u043f\u043e\u0436\u0435\u0440\u0442\u0432\u043e\u0432\u0430\u043d\u0438\u0435  undefined"}, "3": {"effect": 0.0, "value": "\u0431\u0430\u043d\u043a\u043e\u0432\u0441\u043a\u0438\u0435 \u043a\u0430\u0440\u0442\u044b  "}, "4": {"effect": 35.115312043897795, "value": "\u0436\u0435\u043d\u0441\u043a\u0438\u0439                                                                                                                                                                                                                                                   "}, "5": {"effect": 14.454762287457777, "value": "\u043c\u043e\u0441\u043a\u0432\u0430"}, "6": {"effect": -5.24006313751996, "value": 22}, "7": {"effect": -26.116750870843326, "value": 4}, "8": {"effect": 0.0, "value": 2022}, "9": {"effect": 0.0, "value": 18.0}, "10": {"effect": 2.7654993541771007, "value": 7.0}, "11": {"effect": 0.0, "value": 2022.0}, "12": {"effect": -0.20337023494269799, "value": NaN}, "13": {"effect": 0.0, "value": NaN}, "14": {"effect": -0.29699089282933266, "value": NaN}}}, {"outValue": 1026.561196198089, "simIndex": 101.0, "features": {"0": {"effect": -42.47171574973638, "value": "d185b410-aa9a-4870-b39e-9f3f38ff6cb1"}, "1": {"effect": -49.89894258648145, "value": "\u0434\u0430                                                                                                                                                                                                                                                        "}, "2": {"effect ...

# %%
# сортируем объекты по сумме значений SHAP на тестовой выборке 
shap.summary_plot(shap_values, test[X], plot_size=(20,15))

# %%
#посмотреть зависимость предсказаний от конкретного признака в виде 2D графика
features = model.get_feature_importance(prettified=True)['Feature Id'].values

# %%
# посмотреть зависимость предсказаний от конкретного признака в виде 2D графика для всех признаков
for features in features:
    shap.dependence_plot(features, shap_values, test[X])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14031 entries, 9904 to 12503
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         14031 non-null  object
#  1   date                       14031 non-null  datetime64[ns]
#  2   amount                     14031 non-null  float64
#  3   is_reccurent               14031 non-null  object
#  4   purpose                    14031 non-null  object
#  5   channel                    14031 non-null  object
#  6   gender                     14031 non-null  object
#  7   city                       14031 non-null  object
#  8   last_email_activity        14031 non-null  object
#  9   date_day                   14031 non-null  int64
#  10  date_month                 14031 non-null  int64
#  11  date_year                  14031 non-null  int64
#  12  last_email_activity_day    14031 non-null  float64
#  13  last_email_activity_month  14031 non-null  float64
#  14  last_email_activity_year   14031 non-null  float64
#  15  life_time                  14031 non-null  timedelta64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(3), object(7), timedelta64[ns](1)
# memory usage: 2.3+ MB

# %%
train[y].mean(), test[y].mean()
# Out:
# (amount    1140.602789
#  dtype: float64,
#  amount    1301.234319
#  dtype: float64)

# %%
# поменяем тип данных категориальных признаков
for col in ['id', 'is_reccurent', 'purpose', 'channel', 'gender', 'city']:
    df[col] = df[col].astype('category')

# %%
#разбиваем сначала на 2 части обучающую и валидационную (60%),тестовую (40)
train, test = train_test_split(df, train_size=0.60, shuffle=False)   
#разбиваем  обучающую на 2 части: тестовую(50%),валидационную (50)
val, test = train_test_split(test, train_size=0.5,  shuffle=False )

# %%
# список призноков
X = ['id', 'is_reccurent', 'purpose', 'channel', 'gender', 'city',
       'date_day', 'date_month', 'date_year', 'last_email_activity_day',
       'last_email_activity_month', 'last_email_activity_year', 'lag_28',
       'lag_30', 'lag_35', 'lag_42', 'lag_49', 'lag_56', 'rolling_median_7',
       'rolling_median_14', 'rolling_median_28']
# список целевого признака
y=['amount']

#список категориальных признаков
cat_features =['id','is_reccurent', 'purpose', 'channel', 'gender', 'city']

# %%
import lightgbm as lgb
model_lgb = lgb.LGBMRegressor(categorical_feature=cat_features, learning_rate=0.2, max_depth=2, 
                               n_estimators=50, num_leaves = 50,
                               metric = 'RMSE', random_state=42, 
                               num_iteration=700, verbose=-1)

# %%
model_lgb.fit(train[X], train[y], eval_set=(val[X],val[y]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/8m/1_xl2l_10dl223fb3x9qcd480000gn/T/ipykernel_35747/2415603670.py in <module>
# ----> 1 model_lgb.fit(train[X], train[y], eval_set=(val[X],val[y]))
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['lag_28', 'lag_30', 'lag_35', 'lag_42', 'lag_49', 'lag_56', 'rolling_median_7', 'rolling_median_14', 'rolling_median_28'] not in index"

# %%
predicted_LGBMR = model_lgb.predict(val[X])
rmse_LGBMR = mean_squared_error(test[y], predicted_LGBMR)** 0.5
print(rmse_LGBMR)
